# %% [markdown]
# <a href="https://colab.research.google.com/github/ag12s/CreateWithCodeCODES/blob/main/IntroModule/Day-1/A1.0-introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p style="text-align: center;"><font size="8"><b>Section 1.0: Scientific Computing</b></font><br>

# %% [markdown]
# ## What is Scientific Computing?
#
# * Using computers to solve scientific problems
# * How does this relate to Computer Science?
#     + Computer Science creates tools, Scientific Computing uses them
#     + NASA -> Scientific Computing, Microsoft -> Computer Science

# %% [markdown]
# ## What kind of problems can we solve?
#
# Any problem related to science or engineering that is too difficult to do by hand.
#
# For example:
# * Genomic analysis - How closely are 2 species related?
# * Astrophysics - What causes a supernova?
# * Anthropology - Can we estimate the age of someone's death by looking at their bones?
# * City Planning - Can we design a city that takes advantage of natural ventilation?
# * Electromagnetics - How can we manufacture better superconductors?
# * CGI - How can we produce realistic-looking computer graphics, both animated and still images, in real-time?
# * Public Media - 500 hours of video is uploaded to YouTube each minute, can we feasibly check all of this content for copyrighted material?
#
# Believe it or not, these diverse problems share many common threads. This course will explore several important algorithms in scientific computing which are used in some or all of the above problems.

# %% [markdown]
# ## Examples: COVID-19
#
# Do you know where the social distancing recommendation of 6 feet came from last year at the height of the pandemic? Why, scientific simulations with experiments to verify them! Watch the video below (Credit to Ansys company) to see how water droplets from our mouths travel when we cough.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('xSju5sb1br4',start=0)

# %% [markdown]
# ## Examples: Turbulent Fluids
#
# Modeling the chaotic motions of a turbulent fluid is only achievable with a computer program and is very integral to designing efficient, fast, and most importantly SAFE automobiles, airplanes, and even boats! Both liquids and gases/air can experience turbulence when disturbed by chaotic motions and it is important to understand how these motions might interact with solid objects. Turbulence is even an important part in predicting how polluted air from a large forest fire will spread or understanding how the storms on Jupiter form and evolve. In the first image below, we have a very turbulent fluid as evidenced by the strong swirling structures. The second image shows the stormy atmosphere of Jupiter (Credit to eashubble.org and spacetelescope.org). Notice the similarities between the computer-generated turbulence and the telescope image?
#
# ![tburn](https://github.com/ag12s/CreateWithCodeModules/blob/main/images/vorticity_tburn.png?raw=true)
#
# ![jupiter](http://cdn.spacetelescope.org/archives/images/screen/heic2017a.jpg)
#
#
# And finally, we have this short clip of the NASA vortex wake experiments. As you can see, planes themselves create large vortices behind them, I sure wouldn't want to be flying directly behind that!

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('uXrnGiIMGLs',start=0)

# %% [markdown]
# ## Examples: Supernovae - Exploding Stars
#
# Below is an image of a small thermonuclear flame (the little mushroom/finger-like structure in the center) in a very hot and dense channel of unburned gas surrounded by hot ash (the black portions) deep inside of a white dwarf star. This flame is accelerating rapidly and turning into a detonation (rapid, powerful flame) and is potentially a cause for why some stars explode! Believe it or not, this stellar flame behaves much the same as flames on Earth. In fact, some Earth flames can even accelerate into detonations through a similar process as seen in stars and is thought to be a cause for some industrial explosions. Understanding these types of explosions, whether in stars or on Earth goes a long way into knowning how to prevent them, at least on Earth.
#
# ![flame](https://github.com/ag12s/CreateWithCodeModules/blob/main/images/react_sp0007.png?raw=true)

# %% [markdown]
# ## Examples: Computer Generated Graphics
#
# We can even strip back the complexity of the science and mathematics a bit and use mathematical processes to construct interesting and aesthetically pleasing computer graphics, such as the Sierpinski Triangle and Barnsley fern leaf shown below in a combined logo-style graphic. While these graphics are generated with specific, yet simple, mathematics, the general idea can be extended and results in such products as video game graphics and animated movies. In fact, there's often an entire focus by game designers and physicists in making the most realistic water motions and lighting in video games without burning your computer down!
#
# ![recursive](https://github.com/ag12s/CreateWithCodeModules/blob/main/images/recursive_graphics.png?raw=true)

# %% [markdown]
# ## Examples: AI Generated Faces
#
# See all of these faces in the image below (credit to Forbes magazine)? These aren't real people (most likely), but images of faces generated by a machine learning algorithm or AI as some people call it. Don't worry though, AI may be able to generate fake faces, but they won't be taking over the world... they're really only good at finding patterns and categorizing things by those patterns... assuming the programmer who built the AI gave it good rules to search for patterns with... otherwise, it'll be pretty useless! But think about the use of this image generation: Improved NPC design in video games, easy access to stock images for public media (without worry of violating privacy or copyright laws), and more.
#
# ![aifaces](https://thumbor.forbes.com/thumbor/960x0/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F60726abb047c62593256e9b3%2F960x0.jpg%3Ffit%3Dscale)

# %% [markdown]
# ## Computational Thinking
#
# To answer scientific problems, we have to be able to express them in ways that a computer can understand.

# %% [markdown]
# Computational thinking refers to the thought processes involved in expressing solutions as computational steps or algorithms that can be carried out by a computer.
#
# It requires understanding the capabilities of computers, formulating problems to be addressed by a computer, and designing algorithms that a computer can execute. The most effective context and approach for developing computational thinking is learning Computational Science; they are intrinsically connected. Computational thinking is at the heart of the Computational Science practices and is delineated by:
#
# *   Recognizing and Defining Computational Problems
# *   Developing and Using Abstractions
# *   Creating Computational Artifacts
# *   Testing and Refining Computational Artifacts

# %% [markdown]
# # Peanut Butter & Jelly Sandwhich Activity
#
# In this activity you will work in a group to "program" myself and Daryn to make a peanut butter and jelly sandwhich.

# %% [markdown]
# ## What did we learn?
# * Computers take instructions literally, we need to be thorough with our instructions.
# * Computers do exactly what they are told and nothing more.
# * Computers lack the ability to read between the lines.
# * When we are not literal enough, we have to adjust our logic so that the computer does exactly what we want. This is known as *debugging*.

# %% [markdown]
# # Python
#
# * High level computer language - Friendly for beginners!
# * Object oriented
# * Great for scientific computing
# * Popular in both industry and academia
# * Free

# %% [markdown]
# # Terminal Commands
#
# Now we have to return to more terminal/command prompt commands. Files are stored inside folders (or directories), and we have to be able to navigate these folders. In the future, we will be uploading videos to analyze so we will need to be able to check that the video has been uploaded.
#
# The terminal/command prompt has lots of commands. The most important one for us will be the `ls` command.
#
# |Command     |Linux/Mac | Windows|
# |------------|----------|--------|
# |Display current directory| `pwd` | `cd`|
# |Change directory| `cd path`| `cd path`|
# |List contents of directory| `ls`| `dir`|
# |Copy a file/directory| `cp`| `copy`|
# |Move a file/directory| `mv` | `move`|
# |Rename a file/directory| `mv`| `ren`|
# |Delete a file/directory| `rm` | `del`|

# %% [markdown]
# # Google Colabs
#
# For the duration of this camp we will be using Google Colabs. Colab is a Python development environment that runs in the browser using the Google Cloud.
#
# For example, to print "Hello World", just hover the mouse over [ ] and press the play button to the upper left. Or press shift-enter to execute.

# %%
print("Hello World")

# %% [markdown]
# ### Creating and Executing a Code Cell
#
# In the header of this page, you should see a "+ Code" option. If we click on this, we create a new cell below this one where we can include a Python code segment. Let's try it!
#
# * Click the "+ Code" option
# * In that lone cell type "x = 5"
# * Press the *Play* button or hit *Shift+Enter* (at the same time) to execute the cell
# and then hit *Shift+Enter* (at the same time).

# %% [markdown]
# So what did we just do?
#
# We've assigned the label `x` to the number 5. You'll also notice that the label of the cell will now read `[#]:.
#
# * Let's make sure we set the value to x
# * Add another cell and use the print comand to print the value of x

# %% [markdown]
# ### Kernels
#
# You can think of a *kernel* as a seperate Python session. We can assign a variable in one cell and then access it in a seperate cell. The cells are a nice way to divide our code up visually, but everything is connected underneath.
#
# Since each cell is interacting with the same Python instance, if we give `x` a new value and then enter `print(x)` we'll get that new value. Let's try it!
#
# * You will need to create a new cell under this one.
# * Print the existing `x` value
# * Assign x to a new value (anything BUT 5)
# * Print the new value of `x`

# %% [markdown]
# What happens now to `x` if we delete the last cell we created?

# %%
print(x)

# %% [markdown]
# Even though we deleted the cell where we assigned a new value to `x`, the assignment is still valid. This assignment will remain valid until we explicity set `x` to a new value, or until we completely restart the kernel.

# %% [markdown]
# # Restaring the kernel
#
# To restart the kernel
#
# * Select the "Runtime" option
# * Select "Restart Runtime"

# %% [markdown]
# ## Markdown
#
# *Markdown* is a writing format that makes it easy to type formatted text. Cells in Colab can be used for code or to write text in markdown. This lets us write notes that explain what we are doing. These notes can be for ourselves, or to document the work, or to share with others.
#
# To create a markdown cell, click on the `+ Text` option in the header.

# %% [markdown]
# There are several typeseting options in markdown. For italic text, wrap the text in \* :`*this will be italic*`.
#
# For bold wrap the text in \*\*: `** this will be bold **`.
#
# You can create a list using \*: `* item 1`
#                                 `* item 2`

# %% [markdown]
# # Let's try it!
#
# Make a list of 4 grocery items. **Bold** the item you want the most and *italicize*  the item you want the least.
